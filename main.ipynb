# %%
import pandas as pd
import matplotlib.pyplot as mp

# %%
db=pd.read_csv('database.csv')
db.head()
# Out:
#   Category           State/UT  2017  2018  2019  \
# 0    State     Andhra Pradesh   931  1207  1886
# 1    State  Arunachal Pradesh     1     7     8
# 2    State              Assam  1120  2022  2231
# 3    State              Bihar   433   374  1050
# 4    State       Chhattisgarh   171   139   175
#
#    Percentage Share of State/UT (2019)  \
# 0                                  4.2
# 1                                  0.0
# 2                                  5.0
# 3                                  2.4
# 4                                  0.4
#
#    Mid-Year Projected Population (in Lakhs) (2019)  \
# 0                                            523.2
# 1                                             15.1
# 2                                            344.2
# 3                                           1201.1
# 4                                            288.5
#
#    Rate of Total Cyber Crimes (2019)+
# 0                                 3.6
# 1                                 0.5
# ...

# %%
db.columns.values
# Out:
# array(['Category', 'State/UT', '2017', '2018', '2019',
#        'Percentage Share of State/UT (2019)',
#        'Mid-Year Projected Population (in Lakhs) (2019)',
#        'Rate of Total Cyber Crimes (2019)+'], dtype=object)

# %%
db.isna().sum()
# Out:
# Category                                           0
# State/UT                                           0
# 2017                                               0
# 2018                                               0
# 2019                                               0
# Percentage Share of State/UT (2019)                0
# Mid-Year Projected Population (in Lakhs) (2019)    0
# Rate of Total Cyber Crimes (2019)+                 0
# dtype: int64

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 8 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Category                                         39 non-null     object
#  1   State/UT                                         39 non-null     object
#  2   2017                                             39 non-null     int64
#  3   2018                                             39 non-null     int64
#  4   2019                                             39 non-null     int64
#  5   Percentage Share of State/UT (2019)              39 non-null     float64
#  6   Mid-Year Projected Population (in Lakhs) (2019)  39 non-null     float64
#  7   Rate of Total Cyber Crimes (2019)+               39 non-null     float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 2.6+ KB

# %%
db.describe
# Out:
# <bound method NDFrame.describe of        Category           State/UT   2017   2018   2019  \
# 0         State     Andhra Pradesh    931   1207   1886
# 1         State  Arunachal Pradesh      1      7      8
# 2         State              Assam   1120   2022   2231
# 3         State              Bihar    433    374   1050
# 4         State       Chhattisgarh    171    139    175
# 5         State                Goa     13     29     15
# 6         State            Gujarat    458    702    784
# 7         State            Haryana    504    418    564
# 8         State   Himachal Pradesh     56     69     76
# 9         State    Jammu & Kashmir     63     73     73
# 10        State          Jharkhand    720    930   1095
# 11        State          Karnataka   3174   5839  12020
# 12        State             Kerala    320    340    307
# 13        State     Madhya Pradesh    490    740    602
# 14        State        Maharashtra   3604   3511   4967
# ...

# %%
db.plot(kind='bar',x='State/UT',y=['2017','2018','2019','Percentage Share of State/UT (2019)','Mid-Year Projected Population (in Lakhs) (2019)','Rate of Total Cyber Crimes (2019)+'],figsize=(30,20))
# Out:
# <AxesSubplot:xlabel='State/UT'>
